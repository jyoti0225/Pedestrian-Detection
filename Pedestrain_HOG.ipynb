# %%
import cv2 
import imutils
import numpy as np
from imutils.object_detection import non_max_suppression
# %matplotlib inline 
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
def show_image(img):
    cv2_imshow(img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
image = cv2.imread('ped2.jpg') 

# Resizing the Image 
image = imutils.resize(image, width=min(800, image.shape[1])) 
orig = image.copy()   
show_image(orig)
# Out:
# <PIL.Image.Image image mode=RGB size=800x419 at 0x7FF2A7128240>

# %%
# Initializing the HOG person detector 
hog = cv2.HOGDescriptor() 
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# %%
 # Detecting all the regions in the  
# Image that has a pedestrians inside it 
(regions, _) = hog.detectMultiScale(image,  
                                    winStride=(4, 4), 
                                    padding=(4, 4), 
                                    scale=1.05) 
   
# Drawing the regions in the Image 
for (x, y, w, h) in regions: 
    cv2.rectangle(image, (x, y),  
                  (x + w, y + h),  
                  (255, 0, 0), 2) 
    cv2.putText(image,'Person',(int(x),int(y)),cv2.FONT_HERSHEY_COMPLEX,1,(255,255,0))
image= cv2.resize(image, (800,400))
cv2_imshow(image)
# Showing the output Image 
# cv2.imshow("Image", image) 
# cv2.waitKey(0) 
   
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7FF2A71F8550>
